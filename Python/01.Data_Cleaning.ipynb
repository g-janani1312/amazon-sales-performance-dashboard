# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Documents\Data analysis\Project\Amazon Sale Report.csv")
# Out:
# C:\Users\gjana\AppData\Local\Temp\ipykernel_9204\3023822748.py:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Documents\Data analysis\Project\Amazon Sale Report.csv")

# %%
df
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... currency  Amount    ship-city   ship-state  \
# ...

# %%
df.shape
# Out:
# (128975, 24)

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   SKU                 128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      122103 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
# ...

# %%
df.describe()
# Out:
#                index            Qty         Amount  ship-postal-code
# count  128975.000000  128975.000000  121180.000000     128942.000000
# mean    64487.000000       0.904431     648.561465     463966.236509
# std     37232.019822       0.313354     281.211687     191476.764941
# min         0.000000       0.000000       0.000000     110001.000000
# 25%     32243.500000       1.000000     449.000000     382421.000000
# 50%     64487.000000       1.000000     605.000000     500033.000000
# 75%     96730.500000       1.000000     788.000000     600024.000000
# max    128974.000000      15.000000    5584.000000     989898.000000

# %%
df.isnull().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# Unnamed: 22           49050
# dtype: int64

# %%
df = df.drop(columns=["index","Unnamed: 22"])

# %%
df
# Out:
#                    Order ID      Date                        Status  \
# 0       405-8078784-5731545  04-30-22                     Cancelled
# 1       171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2       404-0687676-7273146  04-30-22                       Shipped
# 3       403-9615377-8133951  04-30-22                     Cancelled
# 4       407-1069790-7240320  04-30-22                       Shipped
# ...                     ...       ...                           ...
# 128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  408-7436540-8728312  05-31-22                       Shipped
#
#        Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# ...

# %%
df.shape
# Out:
# (128975, 22)

# %%
df.isnull().sum()
# Out:
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# dtype: int64

# %%
df["Date"]=pd.to_datetime(df["Date"], format="%m-%d-%y")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 22 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Order ID            128975 non-null  object
#  1   Date                128975 non-null  datetime64[ns]
#  2   Status              128975 non-null  object
#  3   Fulfilment          128975 non-null  object
#  4   Sales Channel       128975 non-null  object
#  5   ship-service-level  128975 non-null  object
#  6   Style               128975 non-null  object
#  7   SKU                 128975 non-null  object
#  8   Category            128975 non-null  object
#  9   Size                128975 non-null  object
#  10  ASIN                128975 non-null  object
#  11  Courier Status      122103 non-null  object
#  12  Qty                 128975 non-null  int64
#  13  currency            121180 non-null  object
#  14  Amount              121180 non-null  float64
# ...

# %%
df.head()
# Out:
#               Order ID       Date                        Status Fulfilment  \
# 0  405-8078784-5731545 2022-04-30                     Cancelled   Merchant
# 1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer   Merchant
# 2  404-0687676-7273146 2022-04-30                       Shipped     Amazon
# 3  403-9615377-8133951 2022-04-30                     Cancelled   Merchant
# 4  407-1069790-7240320 2022-04-30                       Shipped     Amazon
#
#   Sales Channel  ship-service-level    Style              SKU       Category  \
# 0      Amazon.in           Standard   SET389   SET389-KR-NP-S            Set
# 1      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL          kurta
# 2      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL          kurta
# 3      Amazon.in           Standard    J0341       J0341-DR-L  Western Dress
# 4      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL            Top
#
# ...

# %%
df["Year"]= df["Date"].dt.year

# %%
df["Month"]= df["Date"].dt.month
df["Month_Name"]= df["Date"].dt.month_name()

# %%
df["Day"] = df["Date"].dt.day
df["Day_Name"] = df["Date"].dt.day_name()
df["Quarter"] = df["Date"].dt.quarter

# %%
df.head()
# Out:
#               Order ID       Date                        Status Fulfilment  \
# 0  405-8078784-5731545 2022-04-30                     Cancelled   Merchant
# 1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer   Merchant
# 2  404-0687676-7273146 2022-04-30                       Shipped     Amazon
# 3  403-9615377-8133951 2022-04-30                     Cancelled   Merchant
# 4  407-1069790-7240320 2022-04-30                       Shipped     Amazon
#
#   Sales Channel  ship-service-level    Style              SKU       Category  \
# 0      Amazon.in           Standard   SET389   SET389-KR-NP-S            Set
# 1      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL          kurta
# 2      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL          kurta
# 3      Amazon.in           Standard    J0341       J0341-DR-L  Western Dress
# 4      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL            Top
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 28 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Order ID            128975 non-null  object
#  1   Date                128975 non-null  datetime64[ns]
#  2   Status              128975 non-null  object
#  3   Fulfilment          128975 non-null  object
#  4   Sales Channel       128975 non-null  object
#  5   ship-service-level  128975 non-null  object
#  6   Style               128975 non-null  object
#  7   SKU                 128975 non-null  object
#  8   Category            128975 non-null  object
#  9   Size                128975 non-null  object
#  10  ASIN                128975 non-null  object
#  11  Courier Status      122103 non-null  object
#  12  Qty                 128975 non-null  int64
#  13  currency            121180 non-null  object
#  14  Amount              121180 non-null  float64
# ...

# %% [markdown]
# # Investigate Amount

# %%
df[df["Amount"].isnull()][["Order ID","Status","Qty","Amount","Courier Status"]].head(20)
# Out:
#                 Order ID     Status  Qty  Amount Courier Status
# 8    407-5443024-5233168  Cancelled    0     NaN      Cancelled
# 29   404-5933402-8801952  Cancelled    0     NaN            NaN
# 65   171-4137548-0481151  Cancelled    0     NaN      Cancelled
# 84   403-9950518-0349133  Cancelled    0     NaN      Cancelled
# 95   405-9112089-3379536  Cancelled    0     NaN      Cancelled
# 101  402-7841951-1872363  Cancelled    0     NaN      Cancelled
# 132  171-0293372-4913973  Cancelled    0     NaN      Cancelled
# 139  403-6442534-2769112  Cancelled    0     NaN      Cancelled
# 155  402-8078642-8565124  Cancelled    0     NaN      Cancelled
# 165  406-0218328-1773963  Cancelled    0     NaN      Cancelled
# 205  403-4337144-0984323  Cancelled    0     NaN      Cancelled
# 215  403-5456917-5571511  Cancelled    0     NaN      Cancelled
# 242  404-0634392-1837110  Cancelled    0     NaN      Cancelled
# 249  404-8514200-3544346  Cancelled    0     NaN      Cancelled
# ...

# %% [markdown]
# # Investigate Courier Status

# %%
df[df["Courier Status"].isnull()][["Order ID","Status","Qty","Courier Status"]].head(20)
# Out:
#                 Order ID     Status  Qty Courier Status
# 0    405-8078784-5731545  Cancelled    0            NaN
# 3    403-9615377-8133951  Cancelled    0            NaN
# 23   404-6019946-2909948  Cancelled    0            NaN
# 29   404-5933402-8801952  Cancelled    0            NaN
# 83   404-6522553-9345930  Cancelled    0            NaN
# 178  171-1224053-5752314  Cancelled    0            NaN
# 226  407-4936046-5852304  Cancelled    0            NaN
# 227  407-4936046-5852304  Cancelled    0            NaN
# 250  404-7452877-2137949  Cancelled    0            NaN
# 251  402-2703790-2816329  Cancelled    0            NaN
# 270  407-5600921-2143569  Cancelled    0            NaN
# 324  407-5096970-7475550  Cancelled    0            NaN
# 327  407-9707366-3029944  Cancelled    0            NaN
# 380  404-6026001-1717923  Cancelled    0            NaN
# 404  404-5848202-7366725  Cancelled    0            NaN
# 415  404-5867260-9073129  Cancelled    0            NaN
# ...

# %% [markdown]
# # Investigate fulfilled-by

# %%
df[df["fulfilled-by"].isnull()][["Order ID","Fulfilment","fulfilled-by"]].head(20)
# Out:
#                Order ID Fulfilment fulfilled-by
# 2   404-0687676-7273146     Amazon          NaN
# 4   407-1069790-7240320     Amazon          NaN
# 5   404-1490984-4578765     Amazon          NaN
# 6   408-5748499-6859555     Amazon          NaN
# 8   407-5443024-5233168     Amazon          NaN
# 9   402-4393761-0311520     Amazon          NaN
# 10  407-5633625-6970741     Amazon          NaN
# 11  171-4638481-6326716     Amazon          NaN
# 13  408-7955685-3083534     Amazon          NaN
# 16  406-9379318-6555504     Amazon          NaN
# 17  405-9013803-8009918     Amazon          NaN
# 19  405-5957858-1051546     Amazon          NaN
# 20  405-0607769-0716360     Amazon          NaN
# 21  404-8494550-5860325     Amazon          NaN
# 22  171-1305077-2813934     Amazon          NaN
# 24  402-3384087-4005164     Amazon          NaN
# 27  408-3484251-6901959     Amazon          NaN
# 28  405-7755803-4729935     Amazon          NaN
# 30  171-9040274-9291563     Amazon          NaN
# ...

# %% [markdown]
# # Investigate promotion-ids

# %%
df[df["promotion-ids"].isnull()][["Order ID", "promotion-ids"]].head(20)
# Out:
#                Order ID promotion-ids
# 0   405-8078784-5731545           NaN
# 3   403-9615377-8133951           NaN
# 4   407-1069790-7240320           NaN
# 9   402-4393761-0311520           NaN
# 10  407-5633625-6970741           NaN
# 11  171-4638481-6326716           NaN
# 13  408-7955685-3083534           NaN
# 17  405-9013803-8009918           NaN
# 19  405-5957858-1051546           NaN
# 22  171-1305077-2813934           NaN
# 23  404-6019946-2909948           NaN
# 27  408-3484251-6901959           NaN
# 29  404-5933402-8801952           NaN
# 34  404-7774085-3780319           NaN
# 39  403-4242957-8599555           NaN
# 44  402-7595162-9129931           NaN
# 46  408-3917043-5314763           NaN
# 53  402-1752649-2274748           NaN
# 57  406-8879861-2081117           NaN
# 64  407-2974257-4781134           NaN

# %% [markdown]
# # Investigate Missing Shopping Information

# %%
df[df["ship-state"].isnull()][["Order ID", "Status", "ship-city", "ship-state", "ship-country"]]
# Out:
#                    Order ID                        Status ship-city  \
# 1871    404-0566904-4825137                       Shipped       NaN
# 1872    404-0566904-4825137                       Shipped       NaN
# 8752    406-4003386-8768363                       Shipped       NaN
# 11215   402-0107720-7057168                       Shipped       NaN
# 13252   407-4532637-8415521                     Cancelled       NaN
# 15688   404-9229894-8608305                       Shipped       NaN
# 16787   402-4919636-4333150  Shipped - Delivered to Buyer       NaN
# 18351   405-4927647-8064368                       Shipped       NaN
# 22930   402-8628677-0457954  Shipped - Returned to Seller       NaN
# 24986   406-4079063-8291520                     Cancelled       NaN
# 30379   404-7506843-7913132  Shipped - Delivered to Buyer       NaN
# 37963   407-3064376-9158743                     Cancelled       NaN
# 37964   407-3064376-9158743                     Cancelled       NaN
# ...

# %%
df["Amount"]=df["Amount"].fillna(0)

# %%
df["Courier Status"]=df["Courier Status"].fillna("Cancelled")

# %%
df["fulfilled-by"]=df["fulfilled-by"].fillna("Amazon")

# %%
df["promotion-ids"]=df["promotion-ids"].fillna("No Promotion")

# %%
df["ship-city"] = df["ship-city"].fillna("Unknown")
df["ship-state"] = df["ship-state"].fillna("Unknown")
df["ship-country"] = df["ship-country"].fillna("Unknown")

# %%
df["ship-postal-code"] = df["ship-postal-code"].fillna(0)

# %%
df.isnull().sum()
# Out:
# Order ID                 0
# Date                     0
# Status                   0
# Fulfilment               0
# Sales Channel            0
# ship-service-level       0
# Style                    0
# SKU                      0
# Category                 0
# Size                     0
# ASIN                     0
# Courier Status           0
# Qty                      0
# currency              7795
# Amount                   0
# ship-city                0
# ship-state               0
# ship-postal-code         0
# ship-country             0
# promotion-ids            0
# B2B                      0
# fulfilled-by             0
# Year                     0
# Month                    0
# Month_Name               0
# Day                      0
# Day_Name                 0
# Quarter                  0
# dtype: int64

# %%
df
# Out:
#                    Order ID       Date                        Status  \
# 0       405-8078784-5731545 2022-04-30                     Cancelled
# 1       171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 2       404-0687676-7273146 2022-04-30                       Shipped
# 3       403-9615377-8133951 2022-04-30                     Cancelled
# 4       407-1069790-7240320 2022-04-30                       Shipped
# ...                     ...        ...                           ...
# 128970  406-6001380-7673107 2022-05-31                       Shipped
# 128971  402-9551604-7544318 2022-05-31                       Shipped
# 128972  407-9547469-3152358 2022-05-31                       Shipped
# 128973  402-6184140-0545956 2022-05-31                       Shipped
# 128974  408-7436540-8728312 2022-05-31                       Shipped
#
#        Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# ...

# %%
pd.set_option('display.max.columns',28)

# %%
df
# Out:
#                    Order ID       Date                        Status  \
# 0       405-8078784-5731545 2022-04-30                     Cancelled
# 1       171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 2       404-0687676-7273146 2022-04-30                       Shipped
# 3       403-9615377-8133951 2022-04-30                     Cancelled
# 4       407-1069790-7240320 2022-04-30                       Shipped
# ...                     ...        ...                           ...
# 128970  406-6001380-7673107 2022-05-31                       Shipped
# 128971  402-9551604-7544318 2022-05-31                       Shipped
# 128972  407-9547469-3152358 2022-05-31                       Shipped
# 128973  402-6184140-0545956 2022-05-31                       Shipped
# 128974  408-7436540-8728312 2022-05-31                       Shipped
#
#        Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# ...

# %%
df["currency"]=df["currency"].fillna('INR')

# %%
df.isnull()
# Out:
#         Order ID   Date  Status  Fulfilment  Sales Channel   \
# 0          False  False   False       False           False
# 1          False  False   False       False           False
# 2          False  False   False       False           False
# 3          False  False   False       False           False
# 4          False  False   False       False           False
# ...          ...    ...     ...         ...             ...
# 128970     False  False   False       False           False
# 128971     False  False   False       False           False
# 128972     False  False   False       False           False
# 128973     False  False   False       False           False
# 128974     False  False   False       False           False
#
#         ship-service-level  Style    SKU  Category   Size   ASIN  \
# 0                    False  False  False     False  False  False
# 1                    False  False  False     False  False  False
# ...

# %%
df.isnull().sum()
# Out:
# Order ID              0
# Date                  0
# Status                0
# Fulfilment            0
# Sales Channel         0
# ship-service-level    0
# Style                 0
# SKU                   0
# Category              0
# Size                  0
# ASIN                  0
# Courier Status        0
# Qty                   0
# currency              0
# Amount                0
# ship-city             0
# ship-state            0
# ship-postal-code      0
# ship-country          0
# promotion-ids         0
# B2B                   0
# fulfilled-by          0
# Year                  0
# Month                 0
# Month_Name            0
# Day                   0
# Day_Name              0
# Quarter               0
# dtype: int64

# %%
df["Order ID"].duplicated().sum()
# Out:
# np.int64(8597)

# %%
df[df["Order ID"].duplicated(keep=False)].sort_values("Order ID").head(20)
# Out:
#                    Order ID       Date                        Status  \
# 78939   171-0012693-2893106 2022-05-07                     Cancelled
# 78938   171-0012693-2893106 2022-05-07                     Cancelled
# 91476   171-0014231-7760344 2022-06-29                       Pending
# 91475   171-0014231-7760344 2022-06-29                       Pending
# 24515   171-0015435-1981904 2022-04-16                       Shipped
# 24516   171-0015435-1981904 2022-04-16                       Shipped
# 99357   171-0019960-6156301 2022-06-22                       Shipped
# 99358   171-0019960-6156301 2022-06-22                       Shipped
# 123553  171-0031114-0715560 2022-06-04  Shipped - Delivered to Buyer
# 123554  171-0031114-0715560 2022-06-04  Shipped - Delivered to Buyer
# 55351   171-0032816-1151573 2022-05-27  Shipped - Delivered to Buyer
# 55352   171-0032816-1151573 2022-05-27  Shipped - Delivered to Buyer
# 34983   171-0035451-9642759 2022-04-09                       Shipped
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(6)

# %%
df[df.duplicated(keep=False)]
# Out:
#                   Order ID       Date     Status Fulfilment Sales Channel   \
# 30660  406-0372545-6086735 2022-04-12  Cancelled     Amazon      Amazon.in
# 30661  406-0372545-6086735 2022-04-12  Cancelled     Amazon      Amazon.in
# 41291  408-0373839-4433120 2022-04-05  Cancelled     Amazon      Amazon.in
# 41292  408-0373839-4433120 2022-04-05  Cancelled     Amazon      Amazon.in
# 79844  171-9628368-5329958 2022-05-07  Cancelled     Amazon      Amazon.in
# 79845  171-9628368-5329958 2022-05-07  Cancelled     Amazon      Amazon.in
# 85790  171-3249942-2207542 2022-05-03    Shipped     Amazon      Amazon.in
# 85791  171-3249942-2207542 2022-05-03    Shipped     Amazon      Amazon.in
# 86418  405-8669298-3850736 2022-05-03    Shipped     Amazon      Amazon.in
# 86419  405-8669298-3850736 2022-05-03    Shipped     Amazon      Amazon.in
# 98954  407-4853873-4978725 2022-06-22    Shipped     Amazon      Amazon.in
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (128969, 28)

# %%
df
# Out:
#                    Order ID       Date                        Status  \
# 0       405-8078784-5731545 2022-04-30                     Cancelled
# 1       171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 2       404-0687676-7273146 2022-04-30                       Shipped
# 3       403-9615377-8133951 2022-04-30                     Cancelled
# 4       407-1069790-7240320 2022-04-30                       Shipped
# ...                     ...        ...                           ...
# 128970  406-6001380-7673107 2022-05-31                       Shipped
# 128971  402-9551604-7544318 2022-05-31                       Shipped
# 128972  407-9547469-3152358 2022-05-31                       Shipped
# 128973  402-6184140-0545956 2022-05-31                       Shipped
# 128974  408-7436540-8728312 2022-05-31                       Shipped
#
#        Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# ...

# %%
print(df["ship-state"].unique())
# Out:
# ['MAHARASHTRA' 'KARNATAKA' 'PUDUCHERRY' 'TAMIL NADU' 'UTTAR PRADESH'
#  'CHANDIGARH' 'TELANGANA' 'ANDHRA PRADESH' 'RAJASTHAN' 'DELHI' 'HARYANA'
#  'ASSAM' 'JHARKHAND' 'CHHATTISGARH' 'ODISHA' 'KERALA' 'MADHYA PRADESH'
#  'WEST BENGAL' 'NAGALAND' 'Gujarat' 'UTTARAKHAND' 'BIHAR'
#  'JAMMU & KASHMIR' 'PUNJAB' 'HIMACHAL PRADESH' 'ARUNACHAL PRADESH'
#  'MANIPUR' 'Goa' 'MEGHALAYA' 'GOA' 'TRIPURA' 'LADAKH' 'DADRA AND NAGAR'
#  'SIKKIM' 'Delhi' 'Unknown' 'ANDAMAN & NICOBAR ' 'Punjab' 'Rajshthan'
#  'Manipur' 'rajasthan' 'Odisha' 'NL' 'Bihar' 'MIZORAM' 'punjab'
#  'New Delhi' 'Rajasthan' 'Punjab/Mohali/Zirakpur' 'Puducherry' 'delhi'
#  'RJ' 'Chandigarh' 'orissa' 'LAKSHADWEEP' 'goa' 'PB' 'APO'
#  'Arunachal Pradesh' 'AR' 'Pondicherry' 'Sikkim' 'Arunachal pradesh'
#  'Nagaland' 'bihar' 'Mizoram' 'rajsthan' 'Orissa' 'Rajsthan' 'Meghalaya']

# %%
df["ship-state"] = df["ship-state"].str.strip()

# %%
df["ship-state"]=df["ship-state"].str.title()

# %%
print(df["ship-state"].unique())
# Out:
# ['Maharashtra' 'Karnataka' 'Puducherry' 'Tamil Nadu' 'Uttar Pradesh'
#  'Chandigarh' 'Telangana' 'Andhra Pradesh' 'Rajasthan' 'Delhi' 'Haryana'
#  'Assam' 'Jharkhand' 'Chhattisgarh' 'Odisha' 'Kerala' 'Madhya Pradesh'
#  'West Bengal' 'Nagaland' 'Gujarat' 'Uttarakhand' 'Bihar'
#  'Jammu & Kashmir' 'Punjab' 'Himachal Pradesh' 'Arunachal Pradesh'
#  'Manipur' 'Goa' 'Meghalaya' 'Tripura' 'Ladakh' 'Dadra And Nagar' 'Sikkim'
#  'Unknown' 'Andaman & Nicobar' 'Rajshthan' 'Nl' 'Mizoram' 'New Delhi'
#  'Punjab/Mohali/Zirakpur' 'Rj' 'Orissa' 'Lakshadweep' 'Pb' 'Apo' 'Ar'
#  'Pondicherry' 'Rajsthan']

# %%
df[df["ship-state"].str.startswith("A", na=False)]["ship-state"].unique()
# Out:
# array(['Andhra Pradesh', 'Assam', 'Arunachal Pradesh',
#        'Andaman & Nicobar', 'Apo', 'Ar'], dtype=object)

# %%
state_replace = {"Orissa":"Odisha","Ar":"Arunachal Pradesh","Rj":"Rajasthan",
    "Pb":"Punjab","Nl":"Nagaland","Ap":"Andhra Pradesh","Goa ":"Goa","Delhi ":"Delhi",
    "Unknown":"Unknown","Pondicherry":"Puducherry","Punjab/Mohali/Zirakpur":"Punjab"}

# %%
df["ship-state"] = df["ship-state"].replace(state_replace)

# %%
print(df["ship-state"].unique())
# Out:
# ['Maharashtra' 'Karnataka' 'Puducherry' 'Tamil Nadu' 'Uttar Pradesh'
#  'Chandigarh' 'Telangana' 'Andhra Pradesh' 'Rajasthan' 'Delhi' 'Haryana'
#  'Assam' 'Jharkhand' 'Chhattisgarh' 'Odisha' 'Kerala' 'Madhya Pradesh'
#  'West Bengal' 'Nagaland' 'Gujarat' 'Uttarakhand' 'Bihar'
#  'Jammu & Kashmir' 'Punjab' 'Himachal Pradesh' 'Arunachal Pradesh'
#  'Manipur' 'Goa' 'Meghalaya' 'Tripura' 'Ladakh' 'Dadra And Nagar' 'Sikkim'
#  'Unknown' 'Andaman & Nicobar' 'Rajshthan' 'Mizoram' 'New Delhi'
#  'Lakshadweep' 'Apo' 'Rajsthan']

# %%
state_replace = {"Rajshthan": "Rajasthan","Rajsthan": "Rajasthan","New Delhi": "Delhi","Dadra And Nagar": "Dadra & Nagar Haveli And Daman & Diu","Apo": "Unknown"}
df["ship-state"] = df["ship-state"].replace(state_replace)

# %%
print(df["ship-state"].nunique())
# Out:
# 37

# %%
print(df["ship-city"].nunique())
# Out:
# 8956

# %%
print(sorted(df["ship-city"].unique()))
# Out:
# ['(Chikmagalur disterict).     (N.R pur thaluku)', '(Via Cuncolim)Quepem,South Goa', ',HYDERABAD', ',raibarely road faizabad (Ayodhya)', '..katra', '.Gannavaram', '.azamgarh', '1', '116  B. P. M. B SARANI, UTTARPARA KOTRUNG', '147/19 B Keshab Chandra Sen Street Kolkata nine ma', '53miles', '6th mile tadong', '7BARASAT', 'AAMBY VALLEY', 'ABHAYAPURI', 'ABHAYAPURI, Bongaigaon', 'ABOHAR', 'ABU ROAD', 'ACHALPUR', 'ACHAMPET', 'ACHANTA', 'ACHARAPAKKAM', 'ACHHNERA', 'ADALAJ', 'ADAMPUR', 'ADAPUR', 'ADBHAR', 'ADDAKAL', 'ADDANKI', 'ADICHANALLOOR', 'ADILABAD', 'ADINAD', 'ADIPUR, GANDHIDHAM', 'ADITYANA', 'ADITYAPUR', 'ADONI', 'ADOOR', 'ADOOR, vaddakkedathu cavu', 'ADRA', 'AFZALGARH', 'AGAR', 'AGAR Malwa', 'AGARTALA', 'AGATTI', 'AGIRIPALLE', 'AGRA', 'AGRA 282005', 'AHERI', 'AHIWARA', 'AHMADNAGAR', 'AHMADNAGARA', 'AHMADPUR', 'AHMED NAGAR', 'AHMEDABAD', 'AHMEDABAD 380007', 'AHMEDABAD 380013', 'AHMEDABAD 380014', 'AHMEDABAD,', 'AHMEDABADvasna', 'AHMEDABAd', 'AHMEDNAGAR', 'AHORE', 'AIMANAM', 'AIZAWL',
# ...

# %%
df["ship-city"].value_counts().head(100)
# Out:
# ship-city
# BENGALURU    11216
# HYDERABAD     8074
# MUMBAI        6126
# NEW DELHI     5795
# CHENNAI       5421
#              ...
# KAKINADA       145
# Lucknow        144
# GWALIOR        144
# Ghaziabad      142
# AMRITSAR       142
# Name: count, Length: 100, dtype: int64

# %%
df["ship-city"] = df["ship-city"].str.strip()
df["ship-city"] = df["ship-city"].str.title()

# %%
df["ship-city"] = df["ship-city"].str.replace(r"\s+", " ")

# %%
df["ship-city"].value_counts().head(100)
# Out:
# ship-city
# Bengaluru             11897
# Hyderabad              9125
# Mumbai                 7122
# New Delhi              6340
# Chennai                6284
# Pune                   4616
# Kolkata                2844
# Gurugram               1954
# Thane                  1877
# Noida                  1627
# Lucknow                1627
# Ghaziabad              1484
# Ahmedabad              1444
# Navi Mumbai            1403
# Bangalore              1362
# Jaipur                 1062
# Coimbatore              891
# Visakhapatnam           858
# Faridabad               820
# Patna                   816
# Bhubaneswar             780
# Pimpri Chinchwad        754
# Guwahati                740
# Nagpur                  732
# Vadodara                710
# Thiruvananthapuram      679
# Dehradun                633
# Secunderabad            621
# Surat                   564
# Greater Noida           564
# Indore                  557
# Kalyan                  547
# ...

# %%
pd.set_option('display.max.rows',100)

# %%
df["ship-city"] = df["ship-city"].str.strip()
df["ship-city"] = df["ship-city"].str.title()
city_replace = {
    "Bangalore": "Bengaluru",
    "Gurgaon": "Gurugram",
    "Delhi": "New Delhi",
    "Allahabad": "Prayagraj"
}

df["ship-city"] = df["ship-city"].replace(city_replace)

# %%
df.to_csv("C:/Documents/Data analysis/Project/Amazon_Sales_Clean.csv", index=False)
print("✅ Cleaned dataset exported successfully!")
# Out:
# ✅ Cleaned dataset exported successfully!
